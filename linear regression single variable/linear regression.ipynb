# %%
import pandas as pd

# %%
# seaborn is used for data visualization
import seaborn as sns
from sklearn import linear_model

# %%
# upload dataset by using pandas 
df=pd.read_excel(r"C:\Users\Asus\OneDrive\Desktop\insurance.xlsx")

# %%
df
# Out:
#    age  premium
# 0   25    18000
# 1   30    32000
# 2   35    40000
# 3   40    47000
# 4   45    55000

# %%
sns.lmplot(x='age',y='premium',data=df)

# %%
reg=linear_model.LinearRegression()

# %%
# fit method is used to train data model
reg.fit(df[['age']],df[['premium']])
# Out:
# LinearRegression()

# %%
reg.predict([[21]])
# Out:
# c:\Users\Asus\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[13480.]])

# %%
reg.predict([[50]])
# Out:
# c:\Users\Asus\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[65100.]])

# %% [markdown]
# y=mx+c here m=slope , c= intercept

# %% [markdown]
# slope is also known as coefficient

# %%
reg.coef_
# Out:
# array([[1780.]])

# %%
reg.intercept_
# Out:
# array([-23900.])
